# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

file = "cleanedbeerapipull.csv"
beer_df = pd.read_csv(file)

# %%
beer_df.head(20)
# Out:
#     index                                               data
# 0       0  {'id': 'Ku1a3J', 'name': 'Adnams Ginger Beer',...
# 1       1  {'id': '0S5yCW', 'name': 'Alster', 'nameDispla...
# 2       2  {'id': 'KMcfsN', 'name': 'Altenburger Radler',...
# 3       3  {'id': 't7flbd', 'name': 'Amstel Oud Bruin', '...
# 4       4  {'id': '3Or1VY', 'name': 'Apoldaer Radler', 'n...
# 5       5  {'id': 'iEZqaZ', 'name': 'Bays Light Ale', 'na...
# 6       6  {'id': 'KEhqHy', 'name': 'Beck’s Chilled Orang...
# 7       7  {'id': 'BBsGkH', 'name': 'Beck’s Green Lemon',...
# 8       8  {'id': 'nVb4ti', 'name': 'Beck’s Ice', 'nameDi...
# 9       9  {'id': 'ibUawL', 'name': 'Berliner Kindl Radle...
# 10     10  {'id': 'RVKKEP', 'name': 'Berliner Weisse', 'n...
# 11     11  {'id': 'U3lqIl', 'name': 'Bischoff Radler', 'n...
# 12     12  {'id': 'wKA3eP', 'name': 'Bitburger Radler', '...
# 13     13  {'id': 'irTMtk', 'name': 'Braugold Radler', 'n...
# ...

# %%
beer_df["data"] = beer_df["data"].apply(lambda x : dict(eval(x)) )
beer_df2 = beer_df["data"].apply(pd.Series)

# %%
beer_df2.head(20)
# Out:
#         id                        name                 nameDisplay  \
# 0   Ku1a3J          Adnams Ginger Beer          Adnams Ginger Beer
# 1   0S5yCW                      Alster                      Alster
# 2   KMcfsN          Altenburger Radler          Altenburger Radler
# 3   t7flbd            Amstel Oud Bruin            Amstel Oud Bruin
# 4   3Or1VY             Apoldaer Radler             Apoldaer Radler
# 5   iEZqaZ              Bays Light Ale              Bays Light Ale
# 6   KEhqHy       Beck’s Chilled Orange       Beck’s Chilled Orange
# 7   BBsGkH          Beck’s Green Lemon          Beck’s Green Lemon
# 8   nVb4ti                  Beck’s Ice                  Beck’s Ice
# 9   ibUawL       Berliner Kindl Radler       Berliner Kindl Radler
# 10  RVKKEP             Berliner Weisse             Berliner Weisse
# 11  U3lqIl             Bischoff Radler             Bischoff Radler
# 12  wKA3eP            Bitburger Radler            Bitburger Radler
# ...

# %%
#rerun dict eval on columns: 

# beer_df3 = pd.concat([beer_df2.drop(['style'], axis=1), beer_df2['style'].apply(pd.Series)], axis=1)
beer_df6 = pd.concat([beer_df5.drop(['category'], axis=1), beer_df5['category'].apply(pd.Series)], axis=1)
beer_df6.to_csv('dictlessdata.csv')
# Out:
# C:\Users\Peter\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\api.py:107: RuntimeWarning: '<' not supported between instances of 'str' and 'int', sort order is undefined for incomparable objects
#   result = result.union(other)
# C:\Users\Peter\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\api.py:69: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   index = _union_indexes(indexes, sort=sort)
# C:\Users\Peter\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\api.py:107: RuntimeWarning: '<' not supported between instances of 'int' and 'str', sort order is undefined for incomparable objects
#   result = result.union(other)
